# %%
import tensorflow as tf
#import tensorflow_addons as tsa
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
import tensorflow_addons as tfa
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from datetime import datetime
from IPython import display
import os

# %%
UNSCALED_HEIGHT = 968
UNSCALED_WIDTH = 1296 # TODO: These should be computed, not added manually
IMG_HEIGHT = 256
IMG_WIDTH = 256
INPUT_FOLDER_NAME = 'uv'
COLOR_FOLDER_NAME = 'color'#'color_rend'
BATCH_SIZE = 1 # TODO: Set larger
EPOCHS = 200
UV_CHANNELS = 2 # TODO: Make sure this is in all appropriate places

# %%
# Check how many GPUs are available
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Set up tensorboard
# %load_ext tensorboard

# %%
def generate_temporal_train_test_split(temporal_file_pairs, skip):
    num_pairs = len(temporal_file_pairs)
    
    # Separate train and test by selecting evenly spaced samples throughout the dataset
    train_filenames = [temporal_file_pairs[i] for i in range(num_pairs) if (i % skip) != 0]
    test_filenames = [temporal_file_pairs[i] for i in range(num_pairs) if (i % skip) == 0]
    
    return train_filenames, test_filenames

# %%
def load_train_test_files(skip):
    # Import file names
    # TODO: Check that every input file has an associated color file
    input_filenames = tf.io.gfile.glob('data/' + INPUT_FOLDER_NAME + '/*')
    color_filenames = tf.io.gfile.glob('data/' + COLOR_FOLDER_NAME + '/*')

    # Sort by file name. Assumed to be numbered temporally.
    input_filenames.sort()
    color_filenames.sort()

    # TODO: Set number used in top of file
    NUM_INPUTS = 1000
    input_filenames[0:NUM_INPUTS]
    color_filenames[0:NUM_INPUTS]
    
    # Create input/label pairs
    # TODO: Use entire dataset
    input_color_filenames = list(zip(input_filenames, color_filenames))

    # Separate train and test sets
    train_filenames, test_filenames = generate_temporal_train_test_split(input_color_filenames, skip)
    
    print('First train filenames')
    for f in train_filenames:#[0:5]:
        print(f)

    print('First test filenames')
    for f in test_filenames:#[0:5]:
        print(f)
        
    train_filenames = tf.convert_to_tensor(train_filenames)
    test_filenames = tf.convert_to_tensor(test_filenames)
    
    return train_filenames, test_filenames

# %%
def load_jpg(image_file):
    image = tf.io.read_file(image_file)
    image = tf.image.decode_jpeg(image)
    image = tf.cast(image, tf.float32)

    return image

# %%
def load_raw(raw_file):
    raw = tf.io.read_file(raw_file)
    raw = tf.io.decode_raw(raw, tf.float32)
    raw = tf.reshape(raw, (UNSCALED_HEIGHT, UNSCALED_WIDTH, UV_CHANNELS))
    raw = tf.reverse(raw, axis=[0]) # OpenGL flips image vertically
    
    return raw

# %%
# normalizing the images to [-1, 1]
def normalize(image):
    image = (image / 127.5) - 1

    return image

# %%
def resize(image, height, width):
    image = tf.image.resize(image, [height, width],
                            method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

    return image

# %%
def random_crop(input_image, color_image):
    stacked_image = tf.stack([input_image, color_image], axis=0)
    cropped_image = tf.image.random_crop(
      stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])

    return cropped_image[0], cropped_image[1]

# %%
@tf.function()
def random_jitter(input_image, color_image):
    # resizing to 286 x 286 x 3
    input_image, color_image = resize(input_image, color_image, 286, 286)

    # randomly cropping to 256 x 256 x 3
    input_image, color_image = random_crop(input_image, color_image)

    if tf.random.uniform(()) > 0.5:
        # random mirroring
        input_image = tf.image.flip_left_right(input_image)
        color_image = tf.image.flip_left_right(color_image)

    return input_image, color_image

# %%
def load_image_train(file_tup):#, color_file):
    # TODO: Load tuple as function params
    input_file = file_tup[0]
    color_file = file_tup[1]
    input_image = load_raw(input_file)
    color_image = load_jpg(color_file)
    
    input_image = resize(input_image, IMG_HEIGHT, IMG_WIDTH) 
    color_image = resize(color_image, IMG_HEIGHT, IMG_WIDTH) 
    # TODO: Add augmentation of input data
    #input_image, color_image = random_jitter(input_image, color_image)
    # TODO: Potentially remove input normalization once I'm importing correct uv vales
    #input_image = normalize(input_image) # TODO: Don't normalize since values are indices
    color_image = normalize(color_image)
    
    return input_image, color_image

# %%
def load_image_test(file_tup):
    # TODO: Load tuple as function params
    input_file = file_tup[0]
    color_file = file_tup[1]
    input_image = load_raw(input_file)
    color_image = load_jpg(color_file)
 
    input_image = resize(input_image, IMG_HEIGHT, IMG_WIDTH) 
    color_image = resize(color_image, IMG_HEIGHT, IMG_WIDTH) 
    #input_image = normalize(input_image)  # TODO: Don't normalize since values are indices
    color_image = normalize(color_image)

    return input_image, color_image

# %%
# Load filenames of train and test data
train_filenames, test_filenames = load_train_test_files(skip=6)

# Prepare train dataset
train_dataset = tf.data.Dataset.from_tensor_slices(train_filenames)
train_dataset = train_dataset.map(load_image_train,
                                  num_parallel_calls=tf.data.experimental.AUTOTUNE)
train_dataset = train_dataset.shuffle(len(train_filenames))
train_dataset = train_dataset.batch(BATCH_SIZE)

# Prepare test dataset
test_dataset = tf.data.Dataset.from_tensor_slices(test_filenames)
test_dataset = test_dataset.map(load_image_test)
test_dataset = test_dataset.batch(BATCH_SIZE)
# Out:
# First train filenames
# ('data/uv/0000001', 'data/color/0000001.jpg')
# ('data/uv/0000002', 'data/color/0000002.jpg')
# ('data/uv/0000003', 'data/color/0000003.jpg')
# ('data/uv/0000004', 'data/color/0000004.jpg')
# ('data/uv/0000005', 'data/color/0000005.jpg')
# ('data/uv/0000007', 'data/color/0000007.jpg')
# ('data/uv/0000008', 'data/color/0000008.jpg')
# ('data/uv/0000009', 'data/color/0000009.jpg')
# ('data/uv/0000010', 'data/color/0000010.jpg')
# ('data/uv/0000011', 'data/color/0000011.jpg')
# ('data/uv/0000013', 'data/color/0000013.jpg')
# ('data/uv/0000014', 'data/color/0000014.jpg')
# ('data/uv/0000015', 'data/color/0000015.jpg')
# ('data/uv/0000016', 'data/color/0000016.jpg')
# ('data/uv/0000017', 'data/color/0000017.jpg')
# ('data/uv/0000019', 'data/color/0000019.jpg')
# ('data/uv/0000020', 'data/color/0000020.jpg')
# ('data/uv/0000021', 'data/color/0000021.jpg')
# ('data/uv/0000022', 'data/color/0000022.jpg')
# ('data/uv/0000023', 'data/color/0000023.jpg')
# ('data/uv/0000025', 'data/color/0000025.jpg')
# ('data/uv/0000026', 'data/color/0000026.jpg')
# ('data/uv/0000027', 'data/color/0000027.jpg')
# ('data/uv/0000028', 'data/color/0000028.jpg')
# ('data/uv/0000029', 'data/color/0000029.jpg')
# ('data/uv/0000031', 'data/color/0000031.jpg')
# ('data/uv/0000032', 'data/color/0000032.jpg')
# ('data/uv/0000033', 'data/color/0000033.jpg')
# ('data/uv/0000034', 'data/color/0000034.jpg')
# ('data/uv/0000035', 'data/color/0000035.jpg')
# ('data/uv/0000037', 'data/color/0000037.jpg')
# ('data/uv/0000038', 'data/color/0000038.jpg')
# ('data/uv/0000039', 'data/color/0000039.jpg')
# ('data/uv/0000040', 'data/color/0000040.jpg')
# ('data/uv/0000041', 'data/color/0000041.jpg')
# ('data/uv/0000043', 'data/color/0000043.jpg')
# ('data/uv/0000044', 'data/color/0000044.jpg')
# ('data/uv/0000045', 'data/color/0000045.jpg')
# ('data/uv/0000046', 'data/color/0000046.jpg')
# ('data/uv/0000047', 'data/color/0000047.jpg')
# ('data/uv/0000049', 'data/color/0000049.jpg')
# ('data/uv/0000050', 'data/color/0000050.jpg')
# ('data/uv/0000051', 'data/color/0000051.jpg')
# ('data/uv/0000052', 'data/color/0000052.jpg')
# ('data/uv/0000053', 'data/color/0000053.jpg')
# ('data/uv/0000055', 'data/color/0000055.jpg')
# ('data/uv/0000056', 'data/color/0000056.jpg')
# ('data/uv/0000057', 'data/color/0000057.jpg')
# ('data/uv/0000058', 'data/color/0000058.jpg')
# ('data/uv/0000059', 'data/color/0000059.jpg')
# ('data/uv/0000061', 'data/color/0000061.jpg')
# ('data/uv/0000062', 'data/color/0000062.jpg')
# ('data/uv/0000063', 'data/color/0000063.jpg')
# ('data/uv/0000064', 'data/color/0000064.jpg')
# ('data/uv/0000065', 'data/color/0000065.jpg')
# ('data/uv/0000067', 'data/color/0000067.jpg')
# ('data/uv/0000068', 'data/color/0000068.jpg')
# ('data/uv/0000069', 'data/color/0000069.jpg')
# ('data/uv/0000070', 'data/color/0000070.jpg')
# ('data/uv/0000071', 'data/color/0000071.jpg')
# ('data/uv/0000073', 'data/color/0000073.jpg')
# ('data/uv/0000074', 'data/color/0000074.jpg')
# ('data/uv/0000075', 'data/color/0000075.jpg')
# ('data/uv/0000076', 'data/color/0000076.jpg')
# ('data/uv/0000077', 'data/color/0000077.jpg')
# ('data/uv/0000079', 'data/color/0000079.jpg')
# ('data/uv/0000080', 'data/color/0000080.jpg')
# ('data/uv/0000081', 'data/color/0000081.jpg')
# ('data/uv/0000082', 'data/color/0000082.jpg')
# ('data/uv/0000083', 'data/color/0000083.jpg')
# ('data/uv/0000085', 'data/color/0000085.jpg')
# ('data/uv/0000086', 'data/color/0000086.jpg')
# ('data/uv/0000087', 'data/color/0000087.jpg')
# ('data/uv/0000088', 'data/color/0000088.jpg')
# ('data/uv/0000089', 'data/color/0000089.jpg')
# ('data/uv/0000091', 'data/color/0000091.jpg')
# ('data/uv/0000092', 'data/color/0000092.jpg')
# ('data/uv/0000093', 'data/color/0000093.jpg')
# ('data/uv/0000094', 'data/color/0000094.jpg')
# ('data/uv/0000095', 'data/color/0000095.jpg')
# ('data/uv/0000097', 'data/color/0000097.jpg')
# ('data/uv/0000098', 'data/color/0000098.jpg')
# ('data/uv/0000099', 'data/color/0000099.jpg')
# ('data/uv/0000100', 'data/color/0000100.jpg')
# ('data/uv/0000101', 'data/color/0000101.jpg')
# ('data/uv/0000103', 'data/color/0000103.jpg')
# ('data/uv/0000104', 'data/color/0000104.jpg')
# ('data/uv/0000105', 'data/color/0000105.jpg')
# ('data/uv/0000106', 'data/color/0000106.jpg')
# ('data/uv/0000107', 'data/color/0000107.jpg')
# ('data/uv/0000109', 'data/color/0000109.jpg')
# ('data/uv/0000110', 'data/color/0000110.jpg')
# ('data/uv/0000111', 'data/color/0000111.jpg')
# ('data/uv/0000112', 'data/color/0000112.jpg')
# ('data/uv/0000113', 'data/color/0000113.jpg')
# ('data/uv/0000115', 'data/color/0000115.jpg')
# ('data/uv/0000116', 'data/color/0000116.jpg')
# ('data/uv/0000117', 'data/color/0000117.jpg')
# ('data/uv/0000118', 'data/color/0000118.jpg')
# ('data/uv/0000119', 'data/color/0000119.jpg')
# ('data/uv/0000121', 'data/color/0000121.jpg')
# ('data/uv/0000122', 'data/color/0000122.jpg')
# ('data/uv/0000123', 'data/color/0000123.jpg')
# ('data/uv/0000124', 'data/color/0000124.jpg')
# ('data/uv/0000125', 'data/color/0000125.jpg')
# ('data/uv/0000127', 'data/color/0000127.jpg')
# ('data/uv/0000128', 'data/color/0000128.jpg')
# ('data/uv/0000129', 'data/color/0000129.jpg')
# ('data/uv/0000130', 'data/color/0000130.jpg')
# ('data/uv/0000131', 'data/color/0000131.jpg')
# ('data/uv/0000133', 'data/color/0000133.jpg')
# ('data/uv/0000134', 'data/color/0000134.jpg')
# ('data/uv/0000135', 'data/color/0000135.jpg')
# ('data/uv/0000136', 'data/color/0000136.jpg')
# ('data/uv/0000137', 'data/color/0000137.jpg')
# ('data/uv/0000139', 'data/color/0000139.jpg')
# ('data/uv/0000140', 'data/color/0000140.jpg')
# ('data/uv/0000141', 'data/color/0000141.jpg')
# ('data/uv/0000142', 'data/color/0000142.jpg')
# ('data/uv/0000143', 'data/color/0000143.jpg')
# ('data/uv/0000145', 'data/color/0000145.jpg')
# ('data/uv/0000146', 'data/color/0000146.jpg')
# ('data/uv/0000147', 'data/color/0000147.jpg')
# ('data/uv/0000148', 'data/color/0000148.jpg')
# ('data/uv/0000149', 'data/color/0000149.jpg')
# ('data/uv/0000151', 'data/color/0000151.jpg')
# ('data/uv/0000152', 'data/color/0000152.jpg')
# ('data/uv/0000153', 'data/color/0000153.jpg')
# ('data/uv/0000154', 'data/color/0000154.jpg')
# ('data/uv/0000155', 'data/color/0000155.jpg')
# ('data/uv/0000157', 'data/color/0000157.jpg')
# ('data/uv/0000158', 'data/color/0000158.jpg')
# ('data/uv/0000159', 'data/color/0000159.jpg')
# ('data/uv/0000160', 'data/color/0000160.jpg')
# ('data/uv/0000161', 'data/color/0000161.jpg')
# ('data/uv/0000163', 'data/color/0000163.jpg')
# ('data/uv/0000164', 'data/color/0000164.jpg')
# ('data/uv/0000165', 'data/color/0000165.jpg')
# ('data/uv/0000166', 'data/color/0000166.jpg')
# ('data/uv/0000167', 'data/color/0000167.jpg')
# ('data/uv/0000169', 'data/color/0000169.jpg')
# ('data/uv/0000170', 'data/color/0000170.jpg')
# ('data/uv/0000171', 'data/color/0000171.jpg')
# ('data/uv/0000172', 'data/color/0000172.jpg')
# ('data/uv/0000173', 'data/color/0000173.jpg')
# ('data/uv/0000175', 'data/color/0000175.jpg')
# ('data/uv/0000176', 'data/color/0000176.jpg')
# ('data/uv/0000177', 'data/color/0000177.jpg')
# ('data/uv/0000178', 'data/color/0000178.jpg')
# ('data/uv/0000179', 'data/color/0000179.jpg')
# ('data/uv/0000181', 'data/color/0000181.jpg')
# ('data/uv/0000182', 'data/color/0000182.jpg')
# ('data/uv/0000183', 'data/color/0000183.jpg')
# ('data/uv/0000184', 'data/color/0000184.jpg')
# ('data/uv/0000185', 'data/color/0000185.jpg')
# ('data/uv/0000187', 'data/color/0000187.jpg')
# ('data/uv/0000188', 'data/color/0000188.jpg')
# ('data/uv/0000189', 'data/color/0000189.jpg')
# ('data/uv/0000190', 'data/color/0000190.jpg')
# ('data/uv/0000191', 'data/color/0000191.jpg')
# ('data/uv/0000193', 'data/color/0000193.jpg')
# ('data/uv/0000194', 'data/color/0000194.jpg')
# ('data/uv/0000195', 'data/color/0000195.jpg')
# ('data/uv/0000196', 'data/color/0000196.jpg')
# ('data/uv/0000197', 'data/color/0000197.jpg')
# ('data/uv/0000199', 'data/color/0000199.jpg')
# ('data/uv/0000200', 'data/color/0000200.jpg')
# ('data/uv/0000201', 'data/color/0000201.jpg')
# ('data/uv/0000202', 'data/color/0000202.jpg')
# ('data/uv/0000203', 'data/color/0000203.jpg')
# ('data/uv/0000205', 'data/color/0000205.jpg')
# ('data/uv/0000206', 'data/color/0000206.jpg')
# ('data/uv/0000207', 'data/color/0000207.jpg')
# ('data/uv/0000208', 'data/color/0000208.jpg')
# ('data/uv/0000209', 'data/color/0000209.jpg')
# ('data/uv/0000211', 'data/color/0000211.jpg')
# ('data/uv/0000212', 'data/color/0000212.jpg')
# ('data/uv/0000213', 'data/color/0000213.jpg')
# ('data/uv/0000214', 'data/color/0000214.jpg')
# ('data/uv/0000215', 'data/color/0000215.jpg')
# ('data/uv/0000217', 'data/color/0000217.jpg')
# ('data/uv/0000218', 'data/color/0000218.jpg')
# ('data/uv/0000219', 'data/color/0000219.jpg')
# ('data/uv/0000220', 'data/color/0000220.jpg')
# ('data/uv/0000221', 'data/color/0000221.jpg')
# ('data/uv/0000223', 'data/color/0000223.jpg')
# ('data/uv/0000224', 'data/color/0000224.jpg')
# ('data/uv/0000225', 'data/color/0000225.jpg')
# ('data/uv/0000226', 'data/color/0000226.jpg')
# ('data/uv/0000227', 'data/color/0000227.jpg')
# ('data/uv/0000229', 'data/color/0000229.jpg')
# ('data/uv/0000230', 'data/color/0000230.jpg')
# ('data/uv/0000231', 'data/color/0000231.jpg')
# ('data/uv/0000232', 'data/color/0000232.jpg')
# ('data/uv/0000233', 'data/color/0000233.jpg')
# ('data/uv/0000235', 'data/color/0000235.jpg')
# ('data/uv/0000236', 'data/color/0000236.jpg')
# ('data/uv/0000237', 'data/color/0000237.jpg')
# ('data/uv/0000374', 'data/color/0000374.jpg')
# ('data/uv/0000375', 'data/color/0000375.jpg')
# ('data/uv/0000376', 'data/color/0000376.jpg')
# ('data/uv/0000377', 'data/color/0000377.jpg')
# ('data/uv/0000379', 'data/color/0000379.jpg')
# ('data/uv/0000380', 'data/color/0000380.jpg')
# ('data/uv/0000381', 'data/color/0000381.jpg')
# ('data/uv/0000382', 'data/color/0000382.jpg')
# ('data/uv/0000383', 'data/color/0000383.jpg')
# ('data/uv/0000385', 'data/color/0000385.jpg')
# ('data/uv/0000386', 'data/color/0000386.jpg')
# ('data/uv/0000387', 'data/color/0000387.jpg')
# ('data/uv/0000388', 'data/color/0000388.jpg')
# ('data/uv/0000389', 'data/color/0000389.jpg')
# ('data/uv/0000391', 'data/color/0000391.jpg')
# ('data/uv/0000392', 'data/color/0000392.jpg')
# ('data/uv/0000393', 'data/color/0000393.jpg')
# ('data/uv/0000394', 'data/color/0000394.jpg')
# ('data/uv/0000395', 'data/color/0000395.jpg')
# ('data/uv/0000397', 'data/color/0000397.jpg')
# ('data/uv/0000398', 'data/color/0000398.jpg')
# ('data/uv/0000399', 'data/color/0000399.jpg')
# ('data/uv/0000400', 'data/color/0000400.jpg')
# ('data/uv/0000401', 'data/color/0000401.jpg')
# ('data/uv/0000403', 'data/color/0000403.jpg')
# ('data/uv/0000404', 'data/color/0000404.jpg')
# ('data/uv/0000405', 'data/color/0000405.jpg')
# ('data/uv/0000406', 'data/color/0000406.jpg')
# ('data/uv/0000407', 'data/color/0000407.jpg')
# ('data/uv/0000409', 'data/color/0000409.jpg')
# ('data/uv/0000410', 'data/color/0000410.jpg')
# ('data/uv/0000411', 'data/color/0000411.jpg')
# ('data/uv/0000412', 'data/color/0000412.jpg')
# ('data/uv/0000413', 'data/color/0000413.jpg')
# ('data/uv/0000415', 'data/color/0000415.jpg')
# ('data/uv/0000416', 'data/color/0000416.jpg')
# ('data/uv/0000417', 'data/color/0000417.jpg')
# ('data/uv/0000418', 'data/color/0000418.jpg')
# ('data/uv/0000419', 'data/color/0000419.jpg')
# ('data/uv/0000421', 'data/color/0000421.jpg')
# ('data/uv/0000422', 'data/color/0000422.jpg')
# ('data/uv/0000423', 'data/color/0000423.jpg')
# ('data/uv/0000424', 'data/color/0000424.jpg')
# ('data/uv/0000425', 'data/color/0000425.jpg')
# ('data/uv/0000427', 'data/color/0000427.jpg')
# ('data/uv/0000428', 'data/color/0000428.jpg')
# ('data/uv/0000429', 'data/color/0000429.jpg')
# ('data/uv/0000430', 'data/color/0000430.jpg')
# ('data/uv/0000431', 'data/color/0000431.jpg')
# ('data/uv/0000433', 'data/color/0000433.jpg')
# ('data/uv/0000434', 'data/color/0000434.jpg')
# ('data/uv/0000435', 'data/color/0000435.jpg')
# ('data/uv/0000436', 'data/color/0000436.jpg')
# ('data/uv/0000437', 'data/color/0000437.jpg')
# ('data/uv/0000439', 'data/color/0000439.jpg')
# ('data/uv/0000440', 'data/color/0000440.jpg')
# ('data/uv/0000441', 'data/color/0000441.jpg')
# ('data/uv/0000442', 'data/color/0000442.jpg')
# ('data/uv/0000443', 'data/color/0000443.jpg')
# ('data/uv/0000445', 'data/color/0000445.jpg')
# ('data/uv/0000446', 'data/color/0000446.jpg')
# ('data/uv/0000447', 'data/color/0000447.jpg')
# ('data/uv/0000448', 'data/color/0000448.jpg')
# ('data/uv/0000449', 'data/color/0000449.jpg')
# ('data/uv/0000451', 'data/color/0000451.jpg')
# ('data/uv/0000452', 'data/color/0000452.jpg')
# ('data/uv/0000453', 'data/color/0000453.jpg')
# ('data/uv/0000454', 'data/color/0000454.jpg')
# ('data/uv/0000455', 'data/color/0000455.jpg')
# ('data/uv/0000457', 'data/color/0000457.jpg')
# ('data/uv/0000458', 'data/color/0000458.jpg')
# ('data/uv/0000459', 'data/color/0000459.jpg')
# ('data/uv/0000460', 'data/color/0000460.jpg')
# ('data/uv/0000461', 'data/color/0000461.jpg')
# ('data/uv/0000463', 'data/color/0000463.jpg')
# ('data/uv/0000464', 'data/color/0000464.jpg')
# ('data/uv/0000465', 'data/color/0000465.jpg')
# ('data/uv/0000466', 'data/color/0000466.jpg')
# ('data/uv/0000467', 'data/color/0000467.jpg')
# ('data/uv/0000469', 'data/color/0000469.jpg')
# ('data/uv/0000470', 'data/color/0000470.jpg')
# ('data/uv/0000471', 'data/color/0000471.jpg')
# ('data/uv/0000472', 'data/color/0000472.jpg')
# ('data/uv/0000473', 'data/color/0000473.jpg')
# ('data/uv/0000475', 'data/color/0000475.jpg')
# ('data/uv/0000476', 'data/color/0000476.jpg')
# ('data/uv/0000477', 'data/color/0000477.jpg')
# ('data/uv/0000478', 'data/color/0000478.jpg')
# ('data/uv/0000479', 'data/color/0000479.jpg')
# ('data/uv/0000481', 'data/color/0000481.jpg')
# ('data/uv/0000482', 'data/color/0000482.jpg')
# ('data/uv/0000483', 'data/color/0000483.jpg')
# ('data/uv/0000484', 'data/color/0000484.jpg')
# ('data/uv/0000485', 'data/color/0000485.jpg')
# ('data/uv/0000487', 'data/color/0000487.jpg')
# ('data/uv/0000488', 'data/color/0000488.jpg')
# ('data/uv/0000489', 'data/color/0000489.jpg')
# ('data/uv/0000490', 'data/color/0000490.jpg')
# ('data/uv/0000491', 'data/color/0000491.jpg')
# ('data/uv/0000493', 'data/color/0000493.jpg')
# ('data/uv/0000494', 'data/color/0000494.jpg')
# ('data/uv/0000495', 'data/color/0000495.jpg')
# ('data/uv/0000496', 'data/color/0000496.jpg')
# ('data/uv/0000497', 'data/color/0000497.jpg')
# ('data/uv/0000499', 'data/color/0000499.jpg')
# ('data/uv/0000500', 'data/color/0000500.jpg')
# ('data/uv/0000501', 'data/color/0000501.jpg')
# ('data/uv/0000502', 'data/color/0000502.jpg')
# ('data/uv/0000503', 'data/color/0000503.jpg')
# ('data/uv/0000505', 'data/color/0000505.jpg')
# ('data/uv/0000506', 'data/color/0000506.jpg')
# ('data/uv/0000507', 'data/color/0000507.jpg')
# ('data/uv/0000508', 'data/color/0000508.jpg')
# ('data/uv/0000509', 'data/color/0000509.jpg')
# ('data/uv/0000511', 'data/color/0000511.jpg')
# ('data/uv/0000512', 'data/color/0000512.jpg')
# ('data/uv/0000513', 'data/color/0000513.jpg')
# ('data/uv/0000514', 'data/color/0000514.jpg')
# ('data/uv/0000515', 'data/color/0000515.jpg')
# ('data/uv/0000517', 'data/color/0000517.jpg')
# ('data/uv/0000518', 'data/color/0000518.jpg')
# ('data/uv/0000519', 'data/color/0000519.jpg')
# ('data/uv/0000520', 'data/color/0000520.jpg')
# ('data/uv/0000521', 'data/color/0000521.jpg')
# ('data/uv/0000523', 'data/color/0000523.jpg')
# ('data/uv/0000524', 'data/color/0000524.jpg')
# ('data/uv/0000525', 'data/color/0000525.jpg')
# ('data/uv/0000526', 'data/color/0000526.jpg')
# ('data/uv/0000527', 'data/color/0000527.jpg')
# ('data/uv/0000529', 'data/color/0000529.jpg')
# ('data/uv/0000530', 'data/color/0000530.jpg')
# ('data/uv/0000531', 'data/color/0000531.jpg')
# ('data/uv/0000532', 'data/color/0000532.jpg')
# ('data/uv/0000533', 'data/color/0000533.jpg')
# ('data/uv/0000535', 'data/color/0000535.jpg')
# ('data/uv/0000536', 'data/color/0000536.jpg')
# ('data/uv/0000537', 'data/color/0000537.jpg')
# ('data/uv/0000538', 'data/color/0000538.jpg')
# ('data/uv/0000539', 'data/color/0000539.jpg')
# ('data/uv/0000541', 'data/color/0000541.jpg')
# ('data/uv/0000542', 'data/color/0000542.jpg')
# ('data/uv/0000543', 'data/color/0000543.jpg')
# ('data/uv/0000544', 'data/color/0000544.jpg')
# ('data/uv/0000545', 'data/color/0000545.jpg')
# ('data/uv/0000547', 'data/color/0000547.jpg')
# ('data/uv/0000548', 'data/color/0000548.jpg')
# ('data/uv/0000549', 'data/color/0000549.jpg')
# ('data/uv/0000550', 'data/color/0000550.jpg')
# ('data/uv/0000551', 'data/color/0000551.jpg')
# ('data/uv/0000553', 'data/color/0000553.jpg')
# ('data/uv/0000554', 'data/color/0000554.jpg')
# ('data/uv/0000555', 'data/color/0000555.jpg')
# ('data/uv/0000556', 'data/color/0000556.jpg')
# ('data/uv/0000557', 'data/color/0000557.jpg')
# ('data/uv/0000559', 'data/color/0000559.jpg')
# ('data/uv/0000560', 'data/color/0000560.jpg')
# ('data/uv/0000561', 'data/color/0000561.jpg')
# ('data/uv/0000562', 'data/color/0000562.jpg')
# ('data/uv/0000563', 'data/color/0000563.jpg')
# ('data/uv/0000565', 'data/color/0000565.jpg')
# ('data/uv/0000566', 'data/color/0000566.jpg')
# ('data/uv/0000567', 'data/color/0000567.jpg')
# ('data/uv/0000568', 'data/color/0000568.jpg')
# ('data/uv/0000569', 'data/color/0000569.jpg')
# ('data/uv/0000571', 'data/color/0000571.jpg')
# ('data/uv/0000572', 'data/color/0000572.jpg')
# ('data/uv/0000573', 'data/color/0000573.jpg')
# ('data/uv/0000574', 'data/color/0000574.jpg')
# ('data/uv/0000575', 'data/color/0000575.jpg')
# ('data/uv/0000644', 'data/color/0000644.jpg')
# ('data/uv/0000645', 'data/color/0000645.jpg')
# ('data/uv/0000646', 'data/color/0000646.jpg')
# ('data/uv/0000647', 'data/color/0000647.jpg')
# ('data/uv/0000649', 'data/color/0000649.jpg')
# ('data/uv/0000650', 'data/color/0000650.jpg')
# ('data/uv/0000651', 'data/color/0000651.jpg')
# ('data/uv/0000652', 'data/color/0000652.jpg')
# ('data/uv/0000653', 'data/color/0000653.jpg')
# ('data/uv/0000655', 'data/color/0000655.jpg')
# ('data/uv/0000656', 'data/color/0000656.jpg')
# ('data/uv/0000657', 'data/color/0000657.jpg')
# ('data/uv/0000658', 'data/color/0000658.jpg')
# ('data/uv/0000659', 'data/color/0000659.jpg')
# ('data/uv/0000661', 'data/color/0000661.jpg')
# ('data/uv/0000662', 'data/color/0000662.jpg')
# ('data/uv/0000663', 'data/color/0000663.jpg')
# ('data/uv/0000664', 'data/color/0000664.jpg')
# ('data/uv/0000665', 'data/color/0000665.jpg')
# ('data/uv/0000667', 'data/color/0000667.jpg')
# ('data/uv/0000668', 'data/color/0000668.jpg')
# ('data/uv/0000669', 'data/color/0000669.jpg')
# ('data/uv/0000670', 'data/color/0000670.jpg')
# ('data/uv/0000671', 'data/color/0000671.jpg')
# ('data/uv/0000673', 'data/color/0000673.jpg')
# ('data/uv/0000674', 'data/color/0000674.jpg')
# ('data/uv/0000675', 'data/color/0000675.jpg')
# ('data/uv/0000676', 'data/color/0000676.jpg')
# ('data/uv/0000677', 'data/color/0000677.jpg')
# ('data/uv/0000679', 'data/color/0000679.jpg')
# ('data/uv/0000680', 'data/color/0000680.jpg')
# ('data/uv/0000681', 'data/color/0000681.jpg')
# ('data/uv/0000682', 'data/color/0000682.jpg')
# ('data/uv/0000683', 'data/color/0000683.jpg')
# ('data/uv/0000685', 'data/color/0000685.jpg')
# ('data/uv/0000686', 'data/color/0000686.jpg')
# ('data/uv/0000687', 'data/color/0000687.jpg')
# ('data/uv/0000688', 'data/color/0000688.jpg')
# ('data/uv/0000689', 'data/color/0000689.jpg')
# ('data/uv/0000691', 'data/color/0000691.jpg')
# ('data/uv/0000692', 'data/color/0000692.jpg')
# ('data/uv/0000693', 'data/color/0000693.jpg')
# ('data/uv/0000694', 'data/color/0000694.jpg')
# ('data/uv/0000695', 'data/color/0000695.jpg')
# ('data/uv/0000697', 'data/color/0000697.jpg')
# ('data/uv/0000698', 'data/color/0000698.jpg')
# ('data/uv/0000699', 'data/color/0000699.jpg')
# ('data/uv/0000700', 'data/color/0000700.jpg')
# ('data/uv/0000701', 'data/color/0000701.jpg')
# ('data/uv/0000703', 'data/color/0000703.jpg')
# ('data/uv/0000704', 'data/color/0000704.jpg')
# ('data/uv/0000705', 'data/color/0000705.jpg')
# ('data/uv/0000706', 'data/color/0000706.jpg')
# ('data/uv/0000707', 'data/color/0000707.jpg')
# ('data/uv/0000709', 'data/color/0000709.jpg')
# ('data/uv/0000710', 'data/color/0000710.jpg')
# ('data/uv/0000711', 'data/color/0000711.jpg')
# ('data/uv/0000847', 'data/color/0000847.jpg')
# ('data/uv/0000848', 'data/color/0000848.jpg')
# ('data/uv/0000849', 'data/color/0000849.jpg')
# ('data/uv/0000850', 'data/color/0000850.jpg')
# ('data/uv/0000851', 'data/color/0000851.jpg')
# ('data/uv/0000853', 'data/color/0000853.jpg')
# ('data/uv/0000854', 'data/color/0000854.jpg')
# ('data/uv/0000855', 'data/color/0000855.jpg')
# ('data/uv/0000856', 'data/color/0000856.jpg')
# ('data/uv/0000857', 'data/color/0000857.jpg')
# ('data/uv/0000859', 'data/color/0000859.jpg')
# ('data/uv/0000860', 'data/color/0000860.jpg')
# ('data/uv/0000861', 'data/color/0000861.jpg')
# ('data/uv/0000862', 'data/color/0000862.jpg')
# ('data/uv/0000863', 'data/color/0000863.jpg')
# ('data/uv/0000865', 'data/color/0000865.jpg')
# ('data/uv/0000866', 'data/color/0000866.jpg')
# ('data/uv/0000867', 'data/color/0000867.jpg')
# ('data/uv/0000868', 'data/color/0000868.jpg')
# ('data/uv/0000869', 'data/color/0000869.jpg')
# ('data/uv/0000871', 'data/color/0000871.jpg')
# ('data/uv/0000872', 'data/color/0000872.jpg')
# ('data/uv/0000873', 'data/color/0000873.jpg')
# ('data/uv/0000874', 'data/color/0000874.jpg')
# ('data/uv/0000875', 'data/color/0000875.jpg')
# ('data/uv/0000877', 'data/color/0000877.jpg')
# ('data/uv/0000878', 'data/color/0000878.jpg')
# ('data/uv/0000879', 'data/color/0000879.jpg')
# ('data/uv/0000880', 'data/color/0000880.jpg')
# ('data/uv/0000881', 'data/color/0000881.jpg')
# ('data/uv/0000883', 'data/color/0000883.jpg')
# ('data/uv/0000884', 'data/color/0000884.jpg')
# ('data/uv/0000885', 'data/color/0000885.jpg')
# ('data/uv/0000886', 'data/color/0000886.jpg')
# ('data/uv/0000887', 'data/color/0000887.jpg')
# ('data/uv/0000889', 'data/color/0000889.jpg')
# ('data/uv/0000890', 'data/color/0000890.jpg')
# ('data/uv/0000891', 'data/color/0000891.jpg')
# ('data/uv/0000892', 'data/color/0000892.jpg')
# ('data/uv/0000893', 'data/color/0000893.jpg')
# ('data/uv/0000895', 'data/color/0000895.jpg')
# ('data/uv/0000896', 'data/color/0000896.jpg')
# ('data/uv/0000897', 'data/color/0000897.jpg')
# ('data/uv/0000898', 'data/color/0000898.jpg')
# ('data/uv/0000899', 'data/color/0000899.jpg')
# ('data/uv/0000901', 'data/color/0000901.jpg')
# ('data/uv/0000902', 'data/color/0000902.jpg')
# ('data/uv/0000903', 'data/color/0000903.jpg')
# ('data/uv/0000904', 'data/color/0000904.jpg')
# ('data/uv/0000905', 'data/color/0000905.jpg')
# ('data/uv/0000907', 'data/color/0000907.jpg')
# ('data/uv/0000908', 'data/color/0000908.jpg')
# ('data/uv/0000909', 'data/color/0000909.jpg')
# ('data/uv/0000910', 'data/color/0000910.jpg')
# ('data/uv/0000911', 'data/color/0000911.jpg')
# ('data/uv/0000913', 'data/color/0000913.jpg')
# ('data/uv/0000914', 'data/color/0000914.jpg')
# ('data/uv/0000915', 'data/color/0000915.jpg')
# ('data/uv/0000916', 'data/color/0000916.jpg')
# ('data/uv/0000917', 'data/color/0000917.jpg')
# ('data/uv/0000919', 'data/color/0000919.jpg')
# ('data/uv/0000920', 'data/color/0000920.jpg')
# ('data/uv/0000921', 'data/color/0000921.jpg')
# ('data/uv/0000922', 'data/color/0000922.jpg')
# ('data/uv/0000923', 'data/color/0000923.jpg')
# ('data/uv/0000925', 'data/color/0000925.jpg')
# ('data/uv/0000926', 'data/color/0000926.jpg')
# ('data/uv/0000927', 'data/color/0000927.jpg')
# ('data/uv/0000928', 'data/color/0000928.jpg')
# ('data/uv/0000929', 'data/color/0000929.jpg')
# ('data/uv/0000931', 'data/color/0000931.jpg')
# ('data/uv/0000932', 'data/color/0000932.jpg')
# ('data/uv/0000933', 'data/color/0000933.jpg')
# ('data/uv/0000934', 'data/color/0000934.jpg')
# ('data/uv/0000935', 'data/color/0000935.jpg')
# ('data/uv/0000937', 'data/color/0000937.jpg')
# ('data/uv/0000938', 'data/color/0000938.jpg')
# ('data/uv/0000939', 'data/color/0000939.jpg')
# ('data/uv/0000940', 'data/color/0000940.jpg')
# ('data/uv/0000941', 'data/color/0000941.jpg')
# ('data/uv/0000943', 'data/color/0000943.jpg')
# ('data/uv/0000944', 'data/color/0000944.jpg')
# ('data/uv/0000945', 'data/color/0000945.jpg')
# ('data/uv/0000946', 'data/color/0000946.jpg')
# ('data/uv/0000947', 'data/color/0000947.jpg')
# ('data/uv/0000949', 'data/color/0000949.jpg')
# ('data/uv/0000950', 'data/color/0000950.jpg')
# ('data/uv/0000951', 'data/color/0000951.jpg')
# ('data/uv/0000952', 'data/color/0000952.jpg')
# ('data/uv/0000953', 'data/color/0000953.jpg')
# ('data/uv/0000955', 'data/color/0000955.jpg')
# ('data/uv/0000956', 'data/color/0000956.jpg')
# ('data/uv/0000957', 'data/color/0000957.jpg')
# ('data/uv/0000958', 'data/color/0000958.jpg')
# ('data/uv/0000959', 'data/color/0000959.jpg')
# ('data/uv/0000961', 'data/color/0000961.jpg')
# ('data/uv/0000962', 'data/color/0000962.jpg')
# ('data/uv/0000963', 'data/color/0000963.jpg')
# ('data/uv/0000964', 'data/color/0000964.jpg')
# ('data/uv/0000965', 'data/color/0000965.jpg')
# ('data/uv/0000967', 'data/color/0000967.jpg')
# ('data/uv/0000968', 'data/color/0000968.jpg')
# ('data/uv/0000969', 'data/color/0000969.jpg')
# ('data/uv/0000970', 'data/color/0000970.jpg')
# ('data/uv/0000971', 'data/color/0000971.jpg')
# ('data/uv/0000973', 'data/color/0000973.jpg')
# ('data/uv/0000974', 'data/color/0000974.jpg')
# ('data/uv/0000975', 'data/color/0000975.jpg')
# ('data/uv/0000976', 'data/color/0000976.jpg')
# ('data/uv/0000977', 'data/color/0000977.jpg')
# ('data/uv/0000979', 'data/color/0000979.jpg')
# ('data/uv/0000980', 'data/color/0000980.jpg')
# ('data/uv/0000981', 'data/color/0000981.jpg')
# ('data/uv/0000336', 'data/color/0000336.jpg')
# ('data/uv/0000342', 'data/color/0000342.jpg')
# ('data/uv/0000348', 'data/color/0000348.jpg')
# ('data/uv/0000354', 'data/color/0000354.jpg')
# ('data/uv/0000360', 'data/color/0000360.jpg')
# ('data/uv/0000366', 'data/color/0000366.jpg')
# ('data/uv/0000372', 'data/color/0000372.jpg')
# ('data/uv/0000378', 'data/color/0000378.jpg')
# ('data/uv/0000384', 'data/color/0000384.jpg')
# ('data/uv/0000390', 'data/color/0000390.jpg')
# ('data/uv/0000396', 'data/color/0000396.jpg')
# ('data/uv/0000402', 'data/color/0000402.jpg')
# ('data/uv/0000408', 'data/color/0000408.jpg')
# ('data/uv/0000414', 'data/color/0000414.jpg')
# ('data/uv/0000420', 'data/color/0000420.jpg')
# ('data/uv/0000426', 'data/color/0000426.jpg')
# ('data/uv/0000432', 'data/color/0000432.jpg')
# ('data/uv/0000438', 'data/color/0000438.jpg')
# ('data/uv/0000444', 'data/color/0000444.jpg')
# ('data/uv/0000450', 'data/color/0000450.jpg')
# ('data/uv/0000456', 'data/color/0000456.jpg')
# ('data/uv/0000462', 'data/color/0000462.jpg')
# ('data/uv/0000468', 'data/color/0000468.jpg')
# ('data/uv/0000474', 'data/color/0000474.jpg')
# ('data/uv/0000480', 'data/color/0000480.jpg')
# ('data/uv/0000486', 'data/color/0000486.jpg')
# ('data/uv/0000492', 'data/color/0000492.jpg')
# ('data/uv/0000498', 'data/color/0000498.jpg')
# ('data/uv/0000504', 'data/color/0000504.jpg')
# ('data/uv/0000510', 'data/color/0000510.jpg')
# ('data/uv/0000516', 'data/color/0000516.jpg')
# ('data/uv/0000522', 'data/color/0000522.jpg')
# ('data/uv/0000528', 'data/color/0000528.jpg')
# ('data/uv/0000534', 'data/color/0000534.jpg')
# ('data/uv/0000540', 'data/color/0000540.jpg')
# ('data/uv/0000546', 'data/color/0000546.jpg')
# ('data/uv/0000552', 'data/color/0000552.jpg')
# ('data/uv/0000558', 'data/color/0000558.jpg')
# ('data/uv/0000564', 'data/color/0000564.jpg')
# ('data/uv/0000570', 'data/color/0000570.jpg')
# ('data/uv/0000576', 'data/color/0000576.jpg')
# ('data/uv/0000582', 'data/color/0000582.jpg')
# ('data/uv/0000588', 'data/color/0000588.jpg')
# ('data/uv/0000594', 'data/color/0000594.jpg')
# ('data/uv/0000600', 'data/color/0000600.jpg')
# ('data/uv/0000606', 'data/color/0000606.jpg')
# ('data/uv/0000612', 'data/color/0000612.jpg')
# ('data/uv/0000618', 'data/color/0000618.jpg')
# ('data/uv/0000624', 'data/color/0000624.jpg')
# ('data/uv/0000630', 'data/color/0000630.jpg')
# ('data/uv/0000636', 'data/color/0000636.jpg')
# ('data/uv/0000642', 'data/color/0000642.jpg')
# ('data/uv/0000648', 'data/color/0000648.jpg')
# ('data/uv/0000654', 'data/color/0000654.jpg')
# ('data/uv/0000660', 'data/color/0000660.jpg')
# ('data/uv/0000666', 'data/color/0000666.jpg')
# ('data/uv/0000672', 'data/color/0000672.jpg')
# ('data/uv/0000678', 'data/color/0000678.jpg')
# ('data/uv/0000684', 'data/color/0000684.jpg')
# ('data/uv/0000690', 'data/color/0000690.jpg')
# ('data/uv/0000696', 'data/color/0000696.jpg')
# ('data/uv/0000702', 'data/color/0000702.jpg')
# ('data/uv/0000708', 'data/color/0000708.jpg')
# ('data/uv/0000714', 'data/color/0000714.jpg')
# ('data/uv/0000720', 'data/color/0000720.jpg')
# ('data/uv/0000726', 'data/color/0000726.jpg')
# ('data/uv/0000732', 'data/color/0000732.jpg')
# ('data/uv/0000738', 'data/color/0000738.jpg')
# ('data/uv/0000744', 'data/color/0000744.jpg')
# ('data/uv/0000750', 'data/color/0000750.jpg')
# ('data/uv/0000756', 'data/color/0000756.jpg')
# ('data/uv/0000762', 'data/color/0000762.jpg')
# ('data/uv/0000768', 'data/color/0000768.jpg')
# ('data/uv/0000774', 'data/color/0000774.jpg')
# ('data/uv/0000780', 'data/color/0000780.jpg')
# ('data/uv/0000786', 'data/color/0000786.jpg')
# ('data/uv/0000792', 'data/color/0000792.jpg')
# ('data/uv/0000798', 'data/color/0000798.jpg')
# ('data/uv/0000804', 'data/color/0000804.jpg')
# ('data/uv/0000810', 'data/color/0000810.jpg')
# ('data/uv/0000816', 'data/color/0000816.jpg')
# ('data/uv/0000822', 'data/color/0000822.jpg')
# ('data/uv/0000828', 'data/color/0000828.jpg')
# ('data/uv/0000834', 'data/color/0000834.jpg')
# ('data/uv/0000840', 'data/color/0000840.jpg')
# ('data/uv/0000846', 'data/color/0000846.jpg')
# ('data/uv/0000852', 'data/color/0000852.jpg')
# ('data/uv/0000858', 'data/color/0000858.jpg')
# ('data/uv/0000864', 'data/color/0000864.jpg')
# ('data/uv/0000870', 'data/color/0000870.jpg')
# ('data/uv/0000876', 'data/color/0000876.jpg')
# ('data/uv/0000882', 'data/color/0000882.jpg')
# ('data/uv/0000888', 'data/color/0000888.jpg')
# ('data/uv/0000894', 'data/color/0000894.jpg')
# ('data/uv/0000900', 'data/color/0000900.jpg')
# ('data/uv/0000906', 'data/color/0000906.jpg')
# ('data/uv/0000912', 'data/color/0000912.jpg')
# ('data/uv/0000918', 'data/color/0000918.jpg')
# ('data/uv/0000924', 'data/color/0000924.jpg')
# ('data/uv/0000930', 'data/color/0000930.jpg')
# ('data/uv/0000936', 'data/color/0000936.jpg')
# ('data/uv/0000942', 'data/color/0000942.jpg')
# ('data/uv/0000948', 'data/color/0000948.jpg')
# ('data/uv/0000954', 'data/color/0000954.jpg')
# ('data/uv/0000960', 'data/color/0000960.jpg')
# ('data/uv/0000966', 'data/color/0000966.jpg')
# ('data/uv/0000972', 'data/color/0000972.jpg')
# ('data/uv/0000978', 'data/color/0000978.jpg')
# ('data/uv/0000984', 'data/color/0000984.jpg')
# ('data/uv/0000990', 'data/color/0000990.jpg')
# ('data/uv/0000996', 'data/color/0000996.jpg')
# ('data/uv/0001002', 'data/color/0001002.jpg')
# ('data/uv/0001008', 'data/color/0001008.jpg')
# ('data/uv/0001014', 'data/color/0001014.jpg')
# ('data/uv/0001020', 'data/color/0001020.jpg')
# ('data/uv/0001026', 'data/color/0001026.jpg')
# ('data/uv/0001032', 'data/color/0001032.jpg')
# ('data/uv/0001038', 'data/color/0001038.jpg')
# ('data/uv/0001044', 'data/color/0001044.jpg')
# ('data/uv/0001050', 'data/color/0001050.jpg')

# %%
# Display sample on Tensorboard
#file_path = next(iter(train_dataset))
#uv_img, color_img = parse_image(file_path)

#def show(uv_img, color_img, file_path):
#  plt.figure()
#  plt.imshow(image)
#  plt.title(file_path.numpy().decode('utf-8'))
#  plt.axis('off')

#show(uv_img, color_img, file_path)



# Display sample of dataset
plt.figure(figsize=(16,8))
for i in range(4):
    r = np.random.randint(len(train_filenames))
    plt.subplot(2,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    img = load_raw(train_filenames[r,0]).numpy()
    #if i == 0:
    #    print(img[115:120, 115:120])
    plt.imshow(img[:,:,0], cmap=plt.cm.binary)
    plt.xlabel(train_filenames[r,0].numpy())
    plt.subplot(2,4,i+1+4)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    img = plt.imread(train_filenames[r,1].numpy(), format='jpeg')
    #if i == 1:
    #    print(img[115:120, 115:120])
    plt.imshow(img, cmap=plt.cm.binary)
    plt.xlabel(train_filenames[r,1].numpy())
plt.show()

# %%
# https://www.tensorflow.org/guide/keras/custom_layers_and_models
class NeuralTexture(Layer):

    def __init__(self, height, width, channels, **kwargs):
        super(NeuralTexture, self).__init__(**kwargs)
        self.height = height
        self.width = width
        self.size = tf.constant([self.height, self.width], dtype=tf.float32)
        self.channels = channels
        # TODO: Set mean and stddev of initializer
        w_init = tf.random_normal_initializer()
        # TODO: WARNING: Added size 1 to batch dimension but should be something else like '?' or None?
        self.w = tf.Variable(initial_value=w_init(shape=(1, height, width, channels),
                                                  dtype='float32'),
                             trainable=True)
        #self.w = tf.expand_dims(self.w, 0)
        
        # TODO: Should there be a bias as well?

    def call(self, inputs):
        # Remove the third channel (TODO: if it exists anymore?)
        inputs = inputs[:,:,:,0:2] 
        # Scale indices to size of neural texture with the power of broadcasting
        inputs = tf.multiply(inputs, self.size)
        batch, height, width, channels = inputs.shape
        N = height * width
        inputs = tf.reshape(inputs, shape=[-1, N, channels])
        sampled_tex = tfa.image.interpolate_bilinear(self.w, inputs, indexing='xy', name="sampled_texture")
        sampled_tex = tf.reshape(sampled_tex, shape=[-1, height, width, channels])
        return sampled_tex#inputs#tf.matmul(inputs, self.w)
    
    def get_config(self):
        return {'height': self.height, 'width': self.width, 'channels': self.channels}

# %%
class DeferredNeuralRenderer(Layer):
    def __init__(self, **kwargs):
        super(DeferredNeuralRenderer, self).__init__(**kwargs)
    
    def build(self, input_shape):
        print(input_shape)
        lr_alpha = 0.2
        # TODO: Should this be defined indivisually for all layers?
        leakyrelu = tf.keras.layers.LeakyReLU(alpha=lr_alpha)
        
        # TODO: Does conv1 not need any information from input_shape? For example, the number of channels
        self.conv1 = Conv2D(64, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm1 = tfa.layers.InstanceNormalization()
        self.conv2 = Conv2D(128, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm2 = tfa.layers.InstanceNormalization()
        self.conv3 = Conv2D(256, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm3 = tfa.layers.InstanceNormalization()
        self.conv4 = Conv2D(512, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm4 = tfa.layers.InstanceNormalization()
        self.conv5 = Conv2D(512, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm5 = tfa.layers.InstanceNormalization()
        
        self.conv6 = Conv2DTranspose(512, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm6 = tfa.layers.InstanceNormalization()
        self.conv7 = Conv2DTranspose(512, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm7 = tfa.layers.InstanceNormalization()
        self.conv8 = Conv2DTranspose(256, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm8 = tfa.layers.InstanceNormalization()
        self.conv9 = Conv2DTranspose(128, 4, strides=(2, 2), activation = leakyrelu, padding = 'same', kernel_initializer = 'he_normal')
        self.norm9 = tfa.layers.InstanceNormalization()
        self.conv10 = Conv2DTranspose(3, 4, strides=(2, 2), activation = 'tanh', padding = 'same', kernel_initializer = 'glorot_normal')
        #conv10 = Conv2DTranspose(64, 4, stride=(2, 2), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge10)
        #conv10 = Conv2D(3, 1, activation = 'tanh', padding = 'same', kernel_initializer = 'glorot_normal')(conv10)
    
    def call(self, inputs):
        # Encoder Layer 1
        c1 = self.conv1(inputs)
        n1 = self.norm1(c1)
        # Encoder Layer 2
        c2 = self.conv2(n1)
        n2 = self.norm2(c2)
        # Encoder Layer 3
        c3 = self.conv3(c2)
        n3 = self.norm3(c3)
        # Encoder Layer 4
        c4 = self.conv4(c3)
        n4 = self.norm4(c4)
        # Encoder Layer 5
        c5 = self.conv5(c4)
        n5 = self.norm5(c5)

        # Decoder Layer 5
        c6 = self.conv6(c5)
        n6 = self.norm6(c6)
        # Decoder Layer 4
        merge7 = concatenate([n4, n6], axis = 3)
        c7 = self.conv7(merge7)
        n7 = self.norm7(c7)
        # Decoder Layer 3
        merge8 = concatenate([n3, n7], axis = 3)
        c8 = self.conv8(merge8)
        n8 = self.norm8(c8)
        # Decoder Layer 2
        merge9 = concatenate([n2, n8], axis = 3)
        c9 = self.conv9(merge9)
        n9 = self.norm9(c9)
        # Decoder Layer 1
        merge10 = concatenate([n1, n9], axis = 3)
        c10 = self.conv10(merge10)

        return c10

# %%
#num_filters = 8
#filter_size = 8

#model = Sequential([
#  Conv2D(num_filters, filter_size, padding="same", strides=(2, 2), activation='relu'),
#  Conv2DTranspose(3, filter_size, padding="same", strides=(2, 2), activation = 'tanh', kernel_initializer = 'glorot_normal')
#])

# %%
class RenderNet(Model):
    def __init__(self):
        super(RenderNet, self).__init__()
        # TODO: Make size larger and scale UV coords appropriately
        self.neural_texture = NeuralTexture(256, 256, 16)#1024, 1024, 16) # TODO: Change to 512 or 1024
        self.neural_renderer = DeferredNeuralRenderer()

    def call(self, inputs, training=False):
        # TODO: How to augment network for training=True
        x = self.neural_texture(inputs)
        x = self.neural_renderer(x)
        return x

# %%
# Loss function
# Not from logits (non-normalized network output) because the last layer has a tanh activations
#loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=False)
loss_object = tf.keras.losses.MeanAbsoluteError()

# %%
# Optimizer
optimizer = tf.keras.optimizers.Adam(lr = 1e-3)#1e-3)

# %%
model = RenderNet()

#model.compile(optimizer = optimizer, loss = loss_object, metrics = ['accuracy'])
#model.build((None, IMG_HEIGHT, IMG_WIDTH, 3))
#model.summary()

# %%
# Trainable network components
#model = neural_renderer_model_ct(optimizer, loss_object)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit
# https://www.tensorflow.org/guide/keras/train_and_evaluate
#log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# Creates a file writer for the log directory.
#file_writer = tf.summary.create_file_writer(log_dir)
#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
#model.fit(train_dataset, epochs=EPOCHS, validation_data=test_dataset, callbacks=[tensorboard_callback])

# %%
def generate_images(model, test_input, tar):
    prediction = model(test_input, training=True)
    plt.figure(figsize=(15,15))

    # Cut off one dimension
    #print(test_input.shape)
    test_input = test_input[:,:,:,0]

    display_list = [test_input[0], tar[0], prediction[0]]
    title = ['Input Image', 'Ground Truth', 'Predicted Image']

    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i] * 0.5 + 0.5)
        plt.axis('off')
    plt.show()

# %%
for example_input, example_target in train_dataset.take(1):
    generate_images(model, example_input, example_target)
# Out:
# (8, 256, 256, 2)

# %%
# Metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.BinaryAccuracy(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_accuracy = tf.keras.metrics.BinaryAccuracy(name='test_accuracy')

# %%
@tf.function
def train_step(uv_maps, color_images):
    with tf.GradientTape() as tape:
        # training=True is only needed if there are layers with different
        # behavior during training versus inference (e.g. Dropout).
        predictions = model(uv_maps, training=True)
        loss = loss_object(color_images, predictions)
    # TODO: Add if warning that "Gradients do not exist for variables"
    # See: https://www.reddit.com/r/tensorflow/comments/bcl5ke/help_with_custom_training_loops_in_tensorflow_20/
    #gradients = tape.gradient(loss, model.trainable_variables)
    #gradients = [grad if grad is not None else tf.zeros_like(var)
    #             for var, grad in zip(model.trainable_variables, grads)]
    
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    train_loss(loss)
    train_accuracy(color_images, predictions)

# %%
@tf.function
def test_step(uv_maps, color_images):
    # training=False is only needed if there are layers with different
    # behavior during training versus inference (e.g. Dropout).
    predictions = model(uv_maps, training=False)
    t_loss = loss_object(color_images, predictions)

    test_loss(t_loss)
    test_accuracy(color_images, predictions)

# %%
# Log files for tensorboard
current_time = datetime.now().strftime("%Y%m%d-%H%M%S")

train_log_dir = 'logs/gradient_tape/' + current_time + '/train'
test_log_dir = 'logs/gradient_tape/' + current_time + '/test'
input_image_log_dir = "logs/images/" + current_time + '/input'
ground_truth_image_log_dir = "logs/images/" + current_time + '/ground_truth'
predicted_image_log_dir = "logs/images/" + current_time + '/predicted'

train_summary_writer = tf.summary.create_file_writer(train_log_dir)
test_summary_writer = tf.summary.create_file_writer(test_log_dir)
input_image_writer = tf.summary.create_file_writer(input_image_log_dir)
ground_truth_image_writer = tf.summary.create_file_writer(ground_truth_image_log_dir)
predicted_image_writer = tf.summary.create_file_writer(predicted_image_log_dir)

# %%
# Train loop
def disp_image(img, name, epoch):
    # Sets up a timestamped log directory.
    img_log = logdir + "-" + name
    # Creates a file writer for the log directory.
    file_writer = tf.summary.create_file_writer(img_log)

    #print(img.shape)
    #print(img[0,100:105,100:105,1])
    
    # Using the file writer, log the reshaped image.
    with file_writer.as_default():
        tf.summary.image(name, img, step=epoch)
        
for epoch in range(EPOCHS):
    # Reset the metrics at the start of the next epoch
    train_loss.reset_states()
    train_accuracy.reset_states()
    test_loss.reset_states()
    test_accuracy.reset_states()

    # TESTING only
    #display.clear_output(wait=True)
    #for example_input, example_target in test_dataset.take(1):
    #    generate_images(model, example_input, example_target)

    # Write input, ground truth and prediction to tensorboard
    for test_input, test_target in test_dataset.take(1):
        test_pred = model(test_input, training=True) # TODO: training=true necessary?
        with input_image_writer.as_default():
            tf.summary.image('UV Map', test_input, step=epoch)
        with ground_truth_image_writer.as_default():
            tf.summary.image('Ground Truth', test_target, step=epoch)
        with predicted_image_writer.as_default():
            tf.summary.image('Predicted', test_pred, step=epoch)
    
    for uv_maps, color_images in train_dataset:
        train_step(uv_maps, color_images)
    with train_summary_writer.as_default():
        tf.summary.scalar('loss', train_loss.result(), step=epoch)
        tf.summary.scalar('accuracy', train_accuracy.result(), step=epoch)

    for test_uv_maps, test_color_images in test_dataset:
        test_step(test_uv_maps, test_color_images)
    with test_summary_writer.as_default():
        tf.summary.scalar('loss', test_loss.result(), step=epoch)
        tf.summary.scalar('accuracy', test_accuracy.result(), step=epoch)

    template = 'Epoch {}, Loss: {}, Accuracy: {}, Test Loss: {}, Test Accuracy: {}'
    print(template.format(epoch + 1,
                        train_loss.result(),
                        train_accuracy.result() * 100,
                        test_loss.result(),
                        test_accuracy.result() * 100))
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['render_net/deferred_neural_renderer/instance_normalization_4/gamma:0', 'render_net/deferred_neural_renderer/instance_normalization_4/beta:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['render_net/deferred_neural_renderer/instance_normalization_4/gamma:0', 'render_net/deferred_neural_renderer/instance_normalization_4/beta:0'] when minimizing the loss.
# Epoch 1, Loss: 0.39256012439727783, Accuracy: 0.0031421480234712362, Test Loss: 0.35633474588394165, Test Accuracy: 0.01406308263540268
# Epoch 2, Loss: 0.32913097739219666, Accuracy: 0.013822720386087894, Test Loss: 0.3070095181465149, Test Accuracy: 0.014756664633750916
# Epoch 3, Loss: 0.2914690375328064, Accuracy: 0.017356369644403458, Test Loss: 0.28190919756889343, Test Accuracy: 0.02063332125544548
# Epoch 4, Loss: 0.2716611325740814, Accuracy: 0.01902930438518524, Test Loss: 0.2658137083053589, Test Accuracy: 0.022686250507831573
# Epoch 5, Loss: 0.2593773305416107, Accuracy: 0.02060830593109131, Test Loss: 0.2564528286457062, Test Accuracy: 0.020793350413441658
# Epoch 6, Loss: 0.24814221262931824, Accuracy: 0.021634714677929878, Test Loss: 0.2466544210910797, Test Accuracy: 0.02208261750638485
# Epoch 7, Loss: 0.24057215452194214, Accuracy: 0.021871155127882957, Test Loss: 0.23871859908103943, Test Accuracy: 0.022225309163331985
# Epoch 8, Loss: 0.2317349910736084, Accuracy: 0.0224358681589365, Test Loss: 0.23228417336940765, Test Accuracy: 0.022374499589204788
# Epoch 9, Loss: 0.22546440362930298, Accuracy: 0.02280491776764393, Test Loss: 0.22656188905239105, Test Accuracy: 0.022891437634825706
# Epoch 10, Loss: 0.2192533016204834, Accuracy: 0.023523595184087753, Test Loss: 0.22325953841209412, Test Accuracy: 0.023061219602823257
# Epoch 11, Loss: 0.2132273018360138, Accuracy: 0.023465998470783234, Test Loss: 0.21671071648597717, Test Accuracy: 0.02393939159810543
# Epoch 12, Loss: 0.2091825306415558, Accuracy: 0.02370721846818924, Test Loss: 0.21329951286315918, Test Accuracy: 0.023866062983870506
