# %%
import matplotlib.pyplot as plt

# %%
# %run src/dataloader.py

# %%
render_loader = UVDataLoader('data', batch_size=1, shuffle=True, num_workers=0, skip=6, training=True)

# %%
def show_image(image):
    """Show image with landmarks"""
    plt.imshow(image)
    plt.pause(0.001)  # pause a bit so that plots are updated
    plt.show()

# %%
# Show sample of dataset
for i_batch, sample_batched in enumerate(render_loader):
    print(i_batch, sample_batched['uv'].size(),
          sample_batched['color'].size())

    # observe 4th batch and stop.
    if i_batch == 3:
        plt.figure()
        show_image(sample_batched['color'].numpy().transpose((0, 2, 3, 1))[0,:,:,:])
        show_image(sample_batched['uv'].numpy().transpose((0, 2, 3, 1))[0,:,:,0])
        plt.axis('off')
        plt.ioff()
        plt.show()
        break
# Out:
# 0 torch.Size([1, 2, 256, 342]) torch.Size([1, 3, 256, 342])
# 1 torch.Size([1, 2, 256, 342]) torch.Size([1, 3, 256, 342])
# 2 torch.Size([1, 2, 256, 342]) torch.Size([1, 3, 256, 342])
# 3 torch.Size([1, 2, 256, 342]) torch.Size([1, 3, 256, 342])
